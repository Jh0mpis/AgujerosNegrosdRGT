# %% [markdown]
# # Solución rotante dRGT

# %%
import numpy as np
import matplotlib.pyplot as mp
import sympy as sp
from sympy import simplify, Eq, cos, sin, diff
from funcionesUtiles import *
sp.init_printing()
# Out:
# Module FuncionesUtiles was charged

# %% [markdown]
# # 1. Definición de las coordenadas y métrica

# %%
t,r,theta,phi, p, a = sp.symbols("t r \\theta \\phi \\rho a")
Lambda,gamma,zeta = sp.symbols(r"\Lambda \gamma \zeta")
m, alpha, beta, m_g, c = sp.symbols(r" m \alpha \beta m_g \epsilon")
coords = [t,r,theta,phi]
params = [m_g, m, c, alpha, beta,a]

# %%
Lambda = -3*m_g**2*(1+alpha+beta)
display(Lambda)
# Out:
#       2
# -3⋅m_g ⋅(\alpha + \beta + 1)

# %%
gamma = -c*m_g**2*(1+2*alpha+3*beta)
display(gamma)
# Out:
#              2
# -\epsilon⋅m_g ⋅(2⋅\alpha + 3⋅\beta + 1)

# %%
zeta = c**2*m_g**2*(alpha + 3*beta)
zeta
# Out:
#         2    2
# \epsilon ⋅m_g ⋅(\alpha + 3⋅\beta)

# %%
f=1-(1/p**2)*(2*m*r+(Lambda/3)*r**4-gamma*r**3-zeta*r**2)
Delta = p**2*f+a**2*sin(theta)**2

g=sp.Matrix([[0 for i in range(4)] for i in range(4)])
g[0,0] = -simplify(f)
g[1,1] = simplify(p**2/Delta)
g[2,2] = p**2
g[3,3] = simplify((p**2+(f-2)*a**2*sin(theta)**2)*sin(theta)**2)
g[0,3] = simplify(a*sin(theta)**2*(f-1))
g[3,0] = g[0,3]
g
# Out:
# ⎡   ⎛        2    2  2                                  2  3
# ⎢  -⎝\epsilon ⋅m_g ⋅r ⋅(\alpha + 3⋅\beta) - \epsilon⋅m_g ⋅r ⋅(2⋅\alpha + 3⋅\be
# ⎢  ───────────────────────────────────────────────────────────────────────────
# ⎢                                                                     2
# ⎢                                                                 \rho
# ⎢
# ⎢
# ⎢
# ⎢                                                                   0
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                                                                   0
# ⎢
# ⎢    ⎛        2    2                                    2  2
# ⎢a⋅r⋅⎝\epsilon ⋅m_g ⋅r⋅(\alpha + 3⋅\beta) - \epsilon⋅m_g ⋅r ⋅(2⋅\alpha + 3⋅\be
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢                                                                     2
# ⎣                                                                 \rho
#
#               2              2  4                     ⎞
# ta + 1) + \rho  - 2⋅m⋅r + m_g ⋅r ⋅(\alpha + \beta + 1)⎠
# ────────────────────────────────────────────────────────
#
#
#
#
#
#                                                             ──────────────────
#                                                                     2    2  2
#                                                             \epsilon ⋅m_g ⋅r ⋅
#
#
#
#
#                    2  3                     ⎞    2
# ta + 1) - 2⋅m + m_g ⋅r ⋅(\alpha + \beta + 1)⎠⋅sin (\theta)
# ──────────────────────────────────────────────────────────
#
#
#
#
#
#                                                       0
#
#
#
#                                                         2
#                                                     \rho
# ──────────────────────────────────────────────────────────────────────────────
#                                  2  3                                2    2
# (\alpha + 3⋅\beta) - \epsilon⋅m_g ⋅r ⋅(2⋅\alpha + 3⋅\beta + 1) + \rho  + a ⋅si
#
#
#                                                       0
#
#
#
#                                                       0
#
#
#
#
#                                                                           a⋅r⋅
#                                                      0                    ────
#
#
#
#
#
# ─────────────────────────────────────────────────    0
#  2                      2  4
# n (\theta) - 2⋅m⋅r + m_g ⋅r ⋅(\alpha + \beta + 1)
#
#                                                        2
#                                                    \rho
#
#                                                           ⎛    4    2 ⎛
#                                                           ⎝\rho  + a ⋅⎝\epsilo
#                                                      0    ────────────────────
#
#
#
# ⎛        2    2                                    2  2
# ⎝\epsilon ⋅m_g ⋅r⋅(\alpha + 3⋅\beta) - \epsilon⋅m_g ⋅r ⋅(2⋅\alpha + 3⋅\beta +
# ──────────────────────────────────────────────────────────────────────────────
#                                                                  2
#                                                              \rho
#
#
#
#                                                                0
#
#
#
#
#                                                                0
#
#  2    2  2                                  2  3
# n ⋅m_g ⋅r ⋅(\alpha + 3⋅\beta) - \epsilon⋅m_g ⋅r ⋅(2⋅\alpha + 3⋅\beta + 1) - \r
# ──────────────────────────────────────────────────────────────────────────────
#                                                                  2
#                                                              \rho
#
#               2  3                     ⎞    2                         ⎤
# 1) - 2⋅m + m_g ⋅r ⋅(\alpha + \beta + 1)⎠⋅sin (\theta)                 ⎥
# ─────────────────────────────────────────────────────                 ⎥
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#                                                                       ⎥
#   2              2  4                     ⎞    2        ⎞    2        ⎥
# ho  - 2⋅m⋅r + m_g ⋅r ⋅(\alpha + \beta + 1)⎠⋅sin (\theta)⎠⋅sin (\theta)⎥
# ──────────────────────────────────────────────────────────────────────⎥
#                                                                       ⎥
#                                                                       ⎦

# %%
simplify(g.subs(p**2,r**2+a**2*cos(theta)**2).subs(a,0))
# Out:
# ⎡          2    2                                    2  2
# ⎢- \epsilon ⋅m_g ⋅r⋅(\alpha + 3⋅\beta) + \epsilon⋅m_g ⋅r ⋅(2⋅\alpha + 3⋅\beta
# ⎢─────────────────────────────────────────────────────────────────────────────
# ⎢                                                            r
# ⎢
# ⎢
# ⎢                                                            0
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                                                            0
# ⎢
# ⎢
# ⎣                                                            0
#
#                 2  3
# + 1) + 2⋅m - m_g ⋅r ⋅(\alpha + \beta + 1) - r
# ─────────────────────────────────────────────
#
#
#
#                                                ───────────────────────────────
#                                                        2    2
#                                                \epsilon ⋅m_g ⋅r⋅(\alpha + 3⋅\b
#
#
#
#
#
#
#
#
#
#                             0
#
#
#                             r
# ──────────────────────────────────────────────────────────────────────────────
#                    2  2                                     2  3
# eta) - \epsilon⋅m_g ⋅r ⋅(2⋅\alpha + 3⋅\beta + 1) - 2⋅m + m_g ⋅r ⋅(\alpha + \be
#
#
#                             0
#
#
#                             0
#
#                                 ⎤
#                                 ⎥
#              0          0       ⎥
#                                 ⎥
#                                 ⎥
#                                 ⎥
# ───────────  0          0       ⎥
#                                 ⎥
# ta + 1) + r                     ⎥
#                                 ⎥
#               2                 ⎥
#              r          0       ⎥
#                                 ⎥
#                   2    2        ⎥
#              0   r ⋅sin (\theta)⎦

# %% [markdown]
# # 2. Horizonte de eventos

# %%
FHorizonte0 = p**2*f+a**2*sin(theta)**2
FHorizonte0=sp.collect(simplify(sp.expand(FHorizonte0.subs(p**2,r**2+a**2*cos(theta)**2))),r)
FHorizonte0
# Out:
#  2            4 ⎛          2            2      2⎞    3 ⎛
# a  - 2⋅m⋅r + r ⋅⎝\alpha⋅m_g  + \beta⋅m_g  + m_g ⎠ + r ⋅⎝- 2⋅\alpha⋅\epsilon⋅m_
#
#  2                       2               2⎞    2 ⎛               2    2
# g  - 3⋅\beta⋅\epsilon⋅m_g  - \epsilon⋅m_g ⎠ + r ⋅⎝\alpha⋅\epsilon ⋅m_g  + 3⋅\b
#
#             2    2    ⎞
# eta⋅\epsilon ⋅m_g  + 1⎠

# %%
FHorizonte = sp.collect(simplify(subs(FHorizonte0,(p**2,r**2+a**2*cos(theta)**2),(m_g,1),(c,1))),r)
FHorizonte
# Out:
#  2            4                         3                              2
# a  - 2⋅m⋅r + r ⋅(\alpha + \beta + 1) + r ⋅(-2⋅\alpha - 3⋅\beta - 1) + r ⋅(\alp
#
#
# ha + 3⋅\beta + 1)

# %% [markdown]
# ## 2.1. Número de soluciones de horizonte de eventos en el espacio $(\alpha-\beta)$

# %%
alphas=np.linspace(-10,15,100)
betas=np.linspace(-1,6,100)

# %%
sols_M1_a1 = findSolutions(f=subs(FHorizonte,(a,0.2),(m,1)),
                           maxNumOfSols=4,domAndArray=[alpha,alphas],imgAndArray=[beta,betas])

# %%
plot(sols_M1_a1,0.2,1)

# %%
sols_M1_a2 = findSolutions(f=subs(FHorizonte,(a,0.25),(m,1)),
                           maxNumOfSols=4,domAndArray=[alpha,alphas],imgAndArray=[beta,betas])

# %%
mp.figure(figsize=(4.8, 4.8))
mp.scatter(sols_M1_a2[0][0],sols_M1_a2[0][1],s=2,c="k", label="0 soluciones")
mp.scatter(sols_M1_a2[1][0],sols_M1_a2[1][1],s=2,c="b", label="1 solución")
mp.scatter(sols_M1_a2[2][0],sols_M1_a2[2][1],s=2,c="g", label="2 soluciones")
mp.scatter(sols_M1_a2[3][0],sols_M1_a2[3][1],s=2,c="m", label="3 soluciones")
mp.scatter(sols_M1_a2[4][0],sols_M1_a2[4][1],s=2,c="r", label="4 soluciones")

mp.xlabel(r"$\alpha$")
mp.ylabel(r"$\beta$")

mp.title("Espacio ($\\alpha,\\beta$) de soluciónes del agujero\nnegro rotante ($m_g=1$, $\\epsilon=1$, $a=0.25$ y $M=1$).")

mp.legend(bbox_to_anchor=(1,1))

# %%
sols_M1_0=findSolutions(f=subs(FHorizonte,(a,0.35),(m,1)),
                        maxNumOfSols=4,domAndArray=[alpha,alphas],imgAndArray=[beta,betas])

# %%
mp.figure(figsize=(4.8, 4.8))
mp.scatter(sols_M1_0[0][0],sols_M1_0[0][1],s=2,c="k", label="0 soluciones")
mp.scatter(sols_M1_0[1][0],sols_M1_0[1][1],s=2,c="b", label="1 solución")
mp.scatter(sols_M1_0[2][0],sols_M1_0[2][1],s=2,c="g", label="2 soluciones")
mp.scatter(sols_M1_0[3][0],sols_M1_0[3][1],s=2,c="m", label="3 soluciones")
mp.scatter(sols_M1_0[4][0],sols_M1_0[4][1],s=2,c="r", label="4 soluciones")

mp.xlabel(r"$\alpha$")
mp.ylabel(r"$\beta$")

mp.title("Espacio ($\\alpha,\\beta$) de soluciónes del agujero\nnegro rotante ($m_g=1$, $\\epsilon=1$, $a=0.35$ y $M=1$).")

mp.legend(bbox_to_anchor=(1,1))

# %%
sols_M1_a3 = findSolutions(f=subs(FHorizonte,(a,0.5),(m,1)),
                           maxNumOfSols=4,domAndArray=[alpha,alphas],imgAndArray=[beta,betas])

# %%
mp.figure(figsize=(4.8, 4.8))
mp.scatter(sols_M1_a3[0][0],sols_M1_a3[0][1],s=2,c="k", label="0 soluciones")
mp.scatter(sols_M1_a3[1][0],sols_M1_a3[1][1],s=2,c="b", label="1 solución")
mp.scatter(sols_M1_a3[2][0],sols_M1_a3[2][1],s=2,c="g", label="2 soluciones")
mp.scatter(sols_M1_a3[3][0],sols_M1_a3[3][1],s=2,c="m", label="3 soluciones")
mp.scatter(sols_M1_a3[4][0],sols_M1_a3[4][1],s=2,c="r", label="4 soluciones")

mp.xlabel(r"$\alpha$")
mp.ylabel(r"$\beta$")

mp.title("Espacio ($\\alpha,\\beta$) de soluciónes del agujero\nnegro rotante ($m_g=1$, $\\epsilon=1$, $a=0.5$ y $M=1$).")

mp.legend(bbox_to_anchor=(1,1))

# %%
sols_M1_a4 = findSolutions(f=subs(FHorizonte,(a,1),(m,1)),
                           maxNumOfSols=4,domAndArray=[alpha,alphas],imgAndArray=[beta,betas])

# %%
plot(sols_M1_a4, 1,1)

# %%
sols_M1_a5 = findSolutions(f=subs(FHorizonte,(a,1.5),(m,1)),
                           maxNumOfSols=4,domAndArray=[alpha,alphas],imgAndArray=[beta,betas])

# %%
plot(sols_M1_a5, 1.5,1)

# %% [markdown]
# ## 2.2. Comportamiento de la función $\tilde{F}(r,\tilde{r})$

# %%
r_graf=np.linspace(0.01,10,200)
mp.figure(figsize=(4.8, 4.8))
mp.grid(True)
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,0.2))),10,0.5,r_graf,coords,params),"b--", label=r"$\alpha=10$, $\beta=0.5$")
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,0.2))),-3,2.1,r_graf,coords,params),"k--", label=r"$\alpha=-3$, $\beta=2.1$")
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,0.2))),0,0,r_graf,coords,params,m_gVal=0),"r-",label="Kerr")
mp.ylim(-2,2)
#mp.xlim(-0.5,5)
mp.ylabel("$F(r)$")
mp.xlabel(r"$\dfrac{r}{M}$")
mp.title("$F(r)$ respecto del radio del agujero\nnegro con $c=1$, $m_g=1$, $a=0.2$ y $M=1$")
mp.legend()
mp.plot([-0.5,10],[0,0],"k-")
mp.plot([0,0],[-2,2],"k-")

# %%
mp.figure(figsize=(4.8, 4.8))
mp.grid(True)
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,0.25))),10,0.5,r_graf,coords,params),"b--", label=r"$\alpha=10$, $\beta=0.5$")
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,0.25))),-3,2.1,r_graf,coords,params),"k--", label=r"$\alpha=-3$, $\beta=2.1$")
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,0.25))),0,0,r_graf,coords,params,m_gVal=0),"r-",label="Kerr")
mp.ylim(-2,2)
#mp.xlim(-0.5,5)
mp.ylabel("$F(r)$")
mp.xlabel(r"$\dfrac{r}{M}$")
mp.title("$F(r)$ respecto del radio del agujero\nnegro con $c=1$, $m_g=1$, $a=0.25$ y $M=1$")
mp.legend()
mp.plot([-0.5,10],[0,0],"k-")
mp.plot([0,0],[-2,2],"k-")

# %%
mp.figure(figsize=(4.8, 4.8))
mp.grid(True)
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,0.35))),10,0.5,r_graf,coords,params),"b--", label=r"$\alpha=10$, $\beta=0.5$")
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,0.35))),-3,2.1,r_graf,coords,params),"k--", label=r"$\alpha=-3$, $\beta=2.1$")
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,0.35))),0,0,r_graf,coords,params,m_gVal=0),"r-",label="Kerr")
mp.ylim(-2,2)
#mp.xlim(-0.5,5)
mp.ylabel("$F(r)$")
mp.xlabel(r"$\dfrac{r}{M}$")
mp.title("$F(r)$ respecto del radio del agujero\nnegro con $c=1$, $m_g=1$, $a=0.35$ y $M=1$")
mp.legend()
mp.plot([-0.5,10],[0,0],"k-")
mp.plot([0,0],[-2,2],"k-")

# %%
mp.figure(figsize=(4.8, 4.8))
mp.grid(True)
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,0.5))),10,0.5,r_graf,coords,params),"b--", label=r"$\alpha=10$, $\beta=0.5$")
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,0.5))),-3,2.1,r_graf,coords,params),"k--", label=r"$\alpha=-3$, $\beta=2.1$")
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,0.5))),0,0,r_graf,coords,params,m_gVal=0),"r-",label="Kerr")
mp.ylim(-2,2)
#mp.xlim(-0.5,5)
mp.ylabel("$F(r)$")
mp.xlabel(r"$\dfrac{r}{M}$")
mp.title("$F(r)$ respecto del radio del agujero\nnegro con $c=1$, $m_g=1$, $a=0.5$ y $M=1$")
mp.legend()
mp.plot([-0.5,10],[0,0],"k-")
mp.plot([0,0],[-2,2],"k-")

# %%
mp.figure(figsize=(4.8, 4.8))
mp.grid(True)
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,1))),10,0.5,r_graf,coords,params),"b--", label=r"$\alpha=10$, $\beta=0.5$")
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,1))),-3,2.1,r_graf,coords,params),"k--", label=r"$\alpha=-3$, $\beta=2.1$")
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,1))),0,0,r_graf,coords,params,m_gVal=0),"r-",label="Kerr")
mp.ylim(-2,2)
#mp.xlim(-0.5,5)
mp.ylabel("$F(r)$")
mp.xlabel(r"$\dfrac{r}{M}$")
mp.title("$F(r)$ respecto del radio del agujero\nnegro con $c=1$, $m_g=1$, $a=1$ y $M=1$")
mp.legend()
mp.plot([-0.5,10],[0,0],"k-")
mp.plot([0,0],[-2,2],"k-")

# %%
mp.figure(figsize=(4.8, 4.8))
mp.grid(True)
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,1.5))),10,0.5,r_graf,coords,params),"b--", label=r"$\alpha=10$, $\beta=0.5$")
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,1.5))),-3,2.1,r_graf,coords,params),"k--", label=r"$\alpha=-3$, $\beta=2.1$")
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,1.5))),0,0,r_graf,coords,params,m_gVal=0),"r-",label="Kerr")
mp.ylim(-2,2)
#mp.xlim(-0.5,5)
mp.ylabel("$F(r)$")
mp.xlabel(r"$\dfrac{r}{M}$")
mp.title("$F(r)$ respecto del radio del agujero\nnegro con $c=1$, $m_g=1$, $a=1.5$ y $M=1$")
mp.legend()
mp.plot([-0.5,10],[0,0],"k-")
mp.plot([0,0],[-2,2],"k-")

# %%
mp.figure(figsize=(4.8, 4.8))
mp.grid(True)
mp.plot(*graf(simplify(subs(FHorizonte0/r**2,(a,0.72))),10,0.5,r_graf,coords,params),"k--", label=r"$\alpha=-3$, $\beta=2.1$")
mp.ylim(-2,2)
#mp.xlim(-0.5,5)
mp.ylabel("$F(r)$")
mp.xlabel(r"$\dfrac{r}{M}$")
mp.title("$F(r)$ respecto del radio del agujero\nnegro con $c=1$, $m_g=1$, $a=1.5$ y $M=1$")
mp.legend()
mp.plot([-0.5,10],[0,0],"k-")
mp.plot([0,0],[-2,2],"k-")

# %% [markdown]
# # 3. Ergosfera

# %%
Ergo = sp.collect(simplify(subs(p**2*g[0,0],(p**2,r**2+a**2*cos(theta)**2))),r**2)
Ergo
# Out:
#             2  3                             2    2                      2  4
# \epsilon⋅m_g ⋅r ⋅(2⋅\alpha + 3⋅\beta + 1) - a ⋅cos (\theta) + 2⋅m⋅r - m_g ⋅r ⋅
#
#                         2 ⎛          2    2                       ⎞
# (\alpha + \beta + 1) + r ⋅⎝- \epsilon ⋅m_g ⋅(\alpha + 3⋅\beta) - 1⎠

# %%
thetas = np.linspace(0,2)*np.pi
def Ergosphere(Ergo,FHorizonte0,thetas,alphaVal,betaVal,aVal,coords,params,Kerr = False):
    ergosphere = []
    m_gVal = 1
    if Kerr:
        m_gVal = 0
    for angle in thetas:
        ergoSols=[i if i!=None else 0 for i in solve(subs(Ergo,(params[0],m_gVal),(params[2],1),(params[3],alphaVal),(params[4],betaVal),(coords[2],angle),(params[1],1),(params[5],aVal)))]
        ergoSols.sort()
        ergosphere.append(ergoSols[-1])
    rHorizon = [i if i!=None else 0 for i in solve(subs(FHorizonte0,(params[0],m_gVal),(params[2],1),(params[3],alphaVal),(params[4],betaVal),(params[1],1),(params[5],aVal)))]
    rHorizon.sort()
    return np.array(ergosphere)*np.cos(thetas), np.array(ergosphere)*np.sin(thetas), rHorizon[-1]

# %%
mp.figure(figsize=(4.8, 4.8))
alphaVal = -3
betaVal = 2.1
aVal = 3.14
x,y,rHorizon = Ergosphere(Ergo,FHorizonte0,thetas,alphaVal,betaVal,aVal,coords,params)
mp.plot(y,x,c="r", label = "Ergosfera")
mp.plot(rHorizon*np.sin(thetas),rHorizon*np.cos(thetas),c="k",label = "Horizonte de eventos")
mp.title(f"Ergósfera para agujero negro de $c=1$, $m_g=1$, y $M=1$\n con $a={aVal}$, $\\alpha ={alphaVal}$ y $\\beta = {betaVal}$")
mp.legend()
mp.legend(bbox_to_anchor=(1,1))

# %%
mp.figure(figsize=(4.8, 4.8))
alphaVal = -3
betaVal = 2.1
aVal = 2
x,y,rHorizon = Ergosphere(Ergo,FHorizonte0,thetas,alphaVal,betaVal,aVal,coords,params)
mp.plot(y,x,c="r", label = "Ergosfera")
mp.plot(rHorizon*np.sin(thetas),rHorizon*np.cos(thetas),c="k",label = "Horizonte de eventos")
mp.title(f"Ergósfera para agujero negro de $c=1$, $m_g=1$, y $M=1$\n con $a={aVal}$, $\\alpha ={alphaVal}$ y $\\beta = {betaVal}$")
mp.legend()
mp.legend(bbox_to_anchor=(1,1))

# %%
mp.figure(figsize=(4.8, 4.8))
alphaVal = -3
betaVal = 2.1
aVal = 0.99
x,y,rHorizon = Ergosphere(Ergo,FHorizonte0,thetas,alphaVal,betaVal,aVal,coords,params)
mp.plot(y,x,c="r", label = "Ergosfera")
mp.plot(rHorizon*np.sin(thetas),rHorizon*np.cos(thetas),c="k",label = "Horizonte de eventos")
mp.title(f"Ergósfera para agujero negro de $c=1$, $m_g=1$, y $M=1$\n con $a={aVal}$, $\\alpha ={alphaVal}$ y $\\beta = {betaVal}$")
mp.legend()
mp.legend(bbox_to_anchor=(1,1))

# %%
mp.figure(figsize=(4.8, 4.8))
alphaVal = 10
betaVal = 0.5
aVal = 0.5
x,y,rHorizon = Ergosphere(Ergo,FHorizonte0,thetas,alphaVal,betaVal,aVal,coords,params)
mp.plot(y,x,c="r", label = "Ergosfera")
mp.plot(rHorizon*np.sin(thetas),rHorizon*np.cos(thetas),c="k",label = "Horizonte de eventos")
mp.title(f"Ergósfera para agujero negro de $c=1$, $m_g=1$, y $M=1$\n con $a={aVal}$, $\\alpha ={alphaVal}$ y $\\beta = {betaVal}$")
mp.legend()
mp.legend(bbox_to_anchor=(1,1))

# %%
mp.figure(figsize=(4.8, 4.8))
alphaVal = 10
betaVal = 0.5
aVal = 0.72
x,y,rHorizon = Ergosphere(Ergo,FHorizonte0,thetas,alphaVal,betaVal,aVal,coords,params)
mp.plot(y,x,c="r", label = "Ergosfera")
mp.plot(rHorizon*np.sin(thetas),rHorizon*np.cos(thetas),c="k",label = "Horizonte de eventos")
mp.title(f"Ergósfera para agujero negro de $c=1$, $m_g=1$, y $M=1$\n con $a={aVal}$, $\\alpha ={alphaVal}$ y $\\beta = {betaVal}$")
mp.legend()
mp.legend(bbox_to_anchor=(1,1))
